# %%
# Linked List
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None


first  = Node(1)
second = Node(2)
third = Node(3)


first.next = second
second.next = third

head = first

print(head.data)
print(head.next.data)
print(head.next.next.data)
# Out:
# 1
# 2
# 3

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

def print_LL(head):
    temp = head
    while(temp != None):
        print(temp.data)
        temp = temp.next
    temp = head
    while(temp != None):
        print(temp.data)
        temp = temp.next
    return

first = Node(1) #object
second = Node(2)
third = Node(3)

print_LL(head)
# Out:
# 1
# 2
# 3
# 1
# 2
# 3

# %%
# Take input of Linked List
# return head to a newly created LL
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

def print_LL(head):
    temp = head
    while(temp != None):
        print(temp.data,end="->")
        temp = temp.next
    # print()
    return

def take_input():
    value = int(input("Enter the value of Node :- "))
    head = None

    while(value !=-1):
        newNode = Node(value)
        if(head == None):
            head = newNode
        else:
            temp = head
            while(temp.next!=None):
                temp = temp.next
            temp.next = newNode
        
        value = int(input("Enter the value of Node :- "))
    return head
    
newHead = take_input()
print_LL(newHead)
# Out:
# 10->20->30->40->

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

def printll(head):
    temp = head
    while(temp !=None):
        print(temp.data,end="->")
        temp = temp.next
    return

def take_input():
    value = int(input("Enter the value : "))
    head = None
    tail = None
    while(value != -1):
        newNode = Node(value)
        if(head == None):
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
        value = int(input("Enter the value : "))
    return head

newHead = take_input()
printll(newHead)
# Out:
# 10->20->30->

# %%
# Take input of Linked List
# return head to a newly created LL
# Optimized approach
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

def print_LLs(head):
    temp = head
    while(temp != None):
        print(temp.data,end="->")
        temp = temp.next
    # print()
    return

def take_optimized_input():
    value = int(input("Enter the value of Node :- "))
    head = None
    tail = None
    while(value !=-1):
        newNode = Node(value)
        if(head == None):
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
        
        value = int(input("Enter the value of Node :- "))
    return head
    
newHead = take_optimized_input()
print_LLs(newHead)
# Out:
# 1->2->3->4->5->

# %%
# Length of LL in normal way
def length_LL(head):
    temp = head
    ans = 0
    while(temp != None):
        temp = temp.next
        ans += 1
    return ans

headLL = take_optimized_input()
length = length_LL(headLL)
print(length)
# Out:
# 2

# %%
def lengthofLLR(head):
    if head == None:
        return 0
    recursionAns = lengthofLLR(head.next)

    return 1 + recursionAns

headLL = take_optimized_input()
lengthR = lengthofLLR(headLL)
print(lengthR)
# Out:
# 5

# %%
# Insert at head of LL

class Node:
    def __init__(self,value):
        self.data = value
        self.next = None
    
def print_LL(head):
    temp =head
    while(temp!=None):
        print(temp.data,end = "->")
        temp = temp.next
    
    return

def take_in():
    value = int(input("Enter the value"))
    head = None
    tail = None
    while(value != -1):
        newNode = Node(value)
        if(head == None):
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
        value = int(input("Enter the value"))
    
    return head

val = take_in()
print_LL(val)
# Out:
# 1->2->3->4->5->

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

def tookinput():
    val = int(input("Enter the value : "))
    head = None
    tail = None
    while(val != -1):
        newNode = Node(val)
        if (head == None):
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
        val = int(input("Enter the value : "))
    return head

def printL(head):
    temp = head
    while(temp != None):
        print(temp.data,end="->")
        temp = temp.next

    return

def insertAtHead(head,data):
    newNode = Node(data)
    if data == -1:
        return head
    newNode.next = head
    head = newNode
    return head

def inserAtTail(head,data):
    newNode = Node(data)
    if data == -1:
        return head
    if (head is None):
        return newNode
    temp = head
    while(temp.next != None):
        temp = temp.next
    temp.next = newNode

    return head

def insertatTail_Recur(head,data):
    newNode = Node(data)
    if head == None:
        return newNode
  
    head.next = insertatTail_Recur(head.next,data)

    return head

def insertAtIndex(head,data,index):
    newNode = Node(data)
    if index == 0:
        newNode.next = head
        head = newNode
        return head
    
    temp = head
    count = 0
    while (temp != None and count < index -1):
        temp = temp.next
        count += 1 
    if (temp is None):
        print("Index out of bounds")
        return head
    newNode.next = temp.next
    temp.next = newNode
    return head

def deleteNodeLLHEAD(head):
    if head == None:   #My LL is empty
        return None
    newHead = head.next
    return newHead

def is_tail_Node(node):  #supporter function for while(temp.next.next)
    if(node == None):
        return True
    if(node.next == None):
        return True
    return False

def deleteNodeTail(head):
    if (head == None or head.next == None):
        return None
    
    temp = head
    while(temp.next.next != None):
        temp = temp.next
    temp.next = None
    return head

def deleteNodeAtIndex(head,index):
    if head == None:
        print("LL is empty")
        return head
    if (index==0):
        return  head.next
    temp =head
    count = 0

    while(temp != None and count < index - 1 ):
        temp = temp.next
        count += 1

    if temp == None:
        print("Out of bounds")
        return head
    
    nodetobedeleted = temp.next
    nodeafterdeleted = nodetobedeleted.next

    # temp.next = temp.next.next
    temp.next = nodeafterdeleted
    return head

def deletenodebyvalue(head,value):
    if head == None:
        print("LL is empty")
        return None
    if(head.data == value):
        return head.next  #boundary case when head is value
    
    temp = head
    while(temp.next is not None and temp.next.data != value):
        temp = temp.next

    if temp.next is None:
        print("Value not found")
        return head
    
    nodetobedeleted = temp.next
    nodeafterdeleted = nodetobedeleted.next

    temp.next = nodeafterdeleted
    # temp.next = temp.next.next
    return head


def searchNodeValue(head,value):
    if head == None:
        print("LL is empty")
        return None
    temp = head
    index = 0
    while(temp != None):
        if(temp.data == value):
            return index
        temp = temp.next
        index += 1
    
    return "Not found"
    

 
head = tookinput()
print("Linked List : ")
printL(head)
print("\n")
data = int(input("Enter the head value : "))
head = insertAtHead(head,data)
print("After inserting head \n")
printL(head)

print("\n")
data = int(input("Enter the tail value : "))
head = inserAtTail(head,data)
print("After inserting tail \n")
printL(head)

print("\n")
data = int(input("Enter the value to add at given index : "))
index = int(input("Enter the index : "))
print(index)
head = insertAtIndex(head,data,index)
print("After inserting at Index \n")
printL(head)

print("\n")
head = deleteNodeLLHEAD(head)
print("After deleting head node \n")
printL(head)

print("\n")
head = deleteNodeTail(head)
print("After deleting tail node \n")
printL(head)

print("\n")
index = int(input("Enter the index to delete: "))
print(index)
head = deleteNodeAtIndex(head,index)
print("After deleting at Index \n")
printL(head)

print("\n Deleting node by value")
val = int(input("Enter the value to delete: "))
print(val)
head = deletenodebyvalue(head,val)
print("After deleting the value \n")
printL(head)

print("\n Searching for a value in the linked list")
val = int(input("Enter the value to search: "))
print(val)
index = searchNodeValue(head,val)
print("The value is at index: ",index)
# Out:
# Linked List :
# 10->20->30->40->
#
# After inserting head
#
# 100->10->20->30->40->
#
# After inserting tail
#
# 100->10->20->30->40->50->
#
# 1
# After inserting at Index
#
# 100->6->10->20->30->40->50->
#
# After deleting head node
#
# 6->10->20->30->40->50->
#
# After deleting tail node
#
# 6->10->20->30->40->
#
# 1
# After deleting at Index
#
# 6->20->30->40->
#  Deleting node by value
# 30
# After deleting the value
#
# 6->20->40->
#  Searching for a value in the linked list
# 20
# The value is at index:  1

# %%
def createLLFromList(l1):
    # value = int(input("Enter the value of Node :- "))
    head = None
    tail = None
    for value in l1:
        newNode = Node(value)
        if(head == None):
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
            
    return head

res = createLLFromList([1,2,3,4,5])
print_LLs(res)
# Out:
# 1->2->3->4->5->

# %%
def lengthLINK(head):
    temp = head
    ans = 0
    while(temp != None):
        temp = temp.next
        ans += 1
    
    return ans

result = take_input()
lengthLINK(result)
# Out:
# 4

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class LinkedList:
    def __init__(self):
        self.head = None

    # 🔹 Print Linked List
    def print_list(self):
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")

    # 🔹 Insert at Head
    def insert_at_head(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    # 🔹 Insert at Tail
    def insert_at_tail(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    # 🔹 Insert at Position (0-based index)
    def insert_at_position(self, pos, data):
        if pos == 0:
            self.insert_at_head(data)
            return
        
        new_node = Node(data)
        temp = self.head
        count = 0

        while temp and count < pos - 1:
            temp = temp.next
            count += 1

        if temp is None:
            print("Position out of range")
            return

        new_node.next = temp.next
        temp.next = new_node

    # 🔹 Delete Head
    def delete_head(self):
        if not self.head:
            return
        self.head = self.head.next

    # 🔹 Delete Tail
    def delete_tail(self):
        if not self.head:
            return
        
        if not self.head.next:
            self.head = None
            return

        temp = self.head
        while temp.next.next:
            temp = temp.next

        temp.next = None

    # 🔹 Delete by Value
    def delete_by_value(self, value):
        if not self.head:
            return
        
        if self.head.data == value:
            self.head = self.head.next
            return
        
        temp = self.head
        while temp.next and temp.next.data != value:
            temp = temp.next

        if temp.next:
            temp.next = temp.next.next
        else:
            print("Value not found")

    # 🔹 Search
    def search(self, value):
        temp = self.head
        pos = 0
        while temp:
            if temp.data == value:
                return pos
            temp = temp.next
            pos += 1
        return -1

    # 🔹 Length
    def length(self):
        count = 0
        temp = self.head
        while temp:
            count += 1
            temp = temp.next
        return count


ll = LinkedList()

ll.insert_at_head(10)
ll.insert_at_tail(20)
ll.insert_at_tail(30)
ll.insert_at_position(1, 15)

ll.print_list()  # 10 -> 15 -> 20 -> 30 -> None

ll.delete_by_value(20)
ll.print_list()  # 10 -> 15 -> 30 -> None

print("Position of 30:", ll.search(30))
print("Length:", ll.length())
# Out:
# 10 -> 15 -> 20 -> 30 -> None
# 10 -> 15 -> 30 -> None
# Position of 30: 2
# Length: 3

# %%
# Middle of linked list
def lengthOfLL(head):
    if head == None:
        return "Empty LL"
    temp = head
    len =0
    while(temp != None ):
        temp = temp.next
        len += 1

    return len


def middle_ll(head):
    if head == None or head.next == None :
        return head
    length = lengthOfLL(head)
    print("length: ",length)
    middle = length // 2
    print("Middle",middle)
    temp = head
    count = 0
    while count < middle :
        temp = temp.next
        count +=1

    return temp

def fastslowMiddleLL(head):
    if head == None or head.next == None :
        return head
    fast = head
    slow = head
    while fast!=None and fast.next != None:
        slow = slow.next
        fast = fast.next.next
    
    return slow

res = take_optimized_input()
print("Linked List : ")
print_LLs(res)
middledata = middle_ll(res)
print("Middle value : ",middledata.data)

res = take_optimized_input()
print("Linked List : ")
print_LLs(res)
fastslowmiddledata = fastslowMiddleLL(res)
print("Middle value  fast slow: ",fastslowmiddledata.data)
# Out:
# Linked List :
# 1->2->3->4->5->6->length:  6
# Middle 3
# Middle value :  4
# Linked List :
# 11->12->13->14->15->16->17->Middle value  fast slow:  14

# %%
# Merged two sorted linked list 
def mergedsortedlIST(head1,head2):
    if head1 is None:
        return head2
    if head2 is None:
        return head1

    finalhead = None
    finaltail = None
    while(head1 != None and head2 != None):
        if (head1.data < head2.data):
            if finalhead == None:
                finalhead = head1
                finaltail = head1
            else:
                finaltail.next = head1
                finaltail = head1
            head1 = head1.next
        else:
            if finalhead == None:
                finalhead = head2
                finaltail = head2
            else:
                finaltail.next = head2
                finaltail = head2

            head2 = head2.next
        
    if head1 != None:
        finaltail.next = head1
    
    if head2 != None:
        finaltail.next = head2

    return finalhead

print("----Merged Two sorted List -----")
print("Head1 linked ")
res1 = take_optimized_input()
print("Linked List head1 :")
print_LLs(res1)

print("Head2 linked ")
res2 = take_optimized_input()
print("Linked List head2 \n:")
print_LLs(res2)

print("----Merged Two sorted List -----")
merged_list = (mergedsortedlIST(res1,res2))
print_LLs(merged_list)
# Out:
# ----Merged Two sorted List -----
# Head1 linked
# Linked List head1 :
# 2->5->9->10->17->Head2 linked
# Linked List head2
# :
# 3->6->7->----Merged Two sorted List -----
# 2->3->5->6->7->9->10->17->

# %%
# Merged two list

def meli(head1,head2):
    fh = None
    ft = None

    while (head1 is not None and head2 is not None):
        if(head1.data <head2.data):
            if fh == None:
                fh = head1
                ft = head1
            else:
                ft.next = head1
                ft = head1
            head1 = head1.next 
        else:
            if fh == None:
                fh = head2
                ft = head2
            else:
                ft.next = head2
                ft = head2
            head2 = head2.next
    if head1 is not None:
        ft.next = head1
    
    if head2 is not None:
        ft.next = head2

    return fh

print("Merged sorted List")
l11 = [3,5,9,14,18]
l12 = [1,4,10,16,21]
h1 = take_input_from_list(l11)
h2 = take_input_from_list(l12)
printLinkedList(h1)
print("\n")
printLinkedList(h2)
print("\n")
ml = meli(h1,h2)
printLinkedList(ml)
print("\n")
# Out:
# Merged sorted List
# 3->5->9->14->18->
#
# 1->4->10->16->21->
#
# 1->3->4->5->9->10->14->16->18->21->

# %%
class Node:
    def __init__(self,value):
        self.data = value
        self.next = None

def take_input_from_list(l1):
    head = None
    tail = None
    for value in l1:
        newNode = Node(value)
        if head == None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode

    return head

def printLinkedList(head):
    temp = head
    if  head is None:
        return None
    while(temp != None):
        print(temp.data,end='->')
        temp = temp.next

    return 

print("Linked List")
# l1 = [1,2,4,5,6]
res = take_input_from_list([1,2,4,5,6])
printLinkedList(res)
# Out:
# Linked List
# 1->2->4->5->6->

# %%
def reverseLinked(head):
    
    if (head is None or head.next is None):
        return head
    prev = None
    curr = head

    while(curr is not None):
        nextNode = curr.next
        curr.next = prev
        prev = curr
        curr = nextNode

    return prev

head = reverseLinked(createLLFromList([1,2,3,4,5,6]))
printLinkedList(head)
# Out:
# 6->5->4->3->2->1->
